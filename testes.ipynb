# %%
import pandas as pd

df = pd.read_csv('./data/covid19_casos_brasil.csv')

# %%
df.head()
# Out:
#         city  city_ibge_code        date  epidemiological_week  \
# 0  São Paulo       3550308.0  2020-02-25                     9
# 1        NaN            35.0  2020-02-25                     9
# 2  São Paulo       3550308.0  2020-02-26                     9
# 3        NaN            35.0  2020-02-26                     9
# 4  São Paulo       3550308.0  2020-02-27                     9
#
#    estimated_population_2019  is_last  is_repeated  last_available_confirmed  \
# 0                 12252023.0    False        False                         1
# 1                 45919049.0    False        False                         1
# 2                 12252023.0    False        False                         1
# 3                 45919049.0    False        False                         1
# 4                 12252023.0    False        False                         1
#
#    last_available_confirmed_per_100k_inhabitants last_available_date  \
# ...

# %%
filtro = df['city'] == 'Curitiba'
filtroNumeroCasos = df['new_confirmed'] > 250
dfFiltrado = df[filtroNumeroCasos]

dfFiltrado[(dfFiltrado['city'] != 'São Paulo') & (dfFiltrado['city'].notnull())].head(20)
# Out:
#                          city  city_ibge_code        date  \
# 13726          Rio de Janeiro       3304557.0  2020-04-13
# 17941               Fortaleza       2304400.0  2020-04-17
# 18575          Rio de Janeiro       3304557.0  2020-04-17
# 19277               Fortaleza       2304400.0  2020-04-18
# 24424          Rio de Janeiro       3304557.0  2020-04-21
# 25216               Fortaleza       2304400.0  2020-04-22
# 26656                  Manaus       1302603.0  2020-04-23
# 26833               Fortaleza       2304400.0  2020-04-23
# 27663          Rio de Janeiro       3304557.0  2020-04-23
# 28524               Fortaleza       2304400.0  2020-04-24
# 29127  Importados/Indefinidos             NaN  2020-04-24
# 30299               Fortaleza       2304400.0  2020-04-25
# 31202          Rio de Janeiro       3304557.0  2020-04-25
# 32139               Fortaleza       2304400.0  2020-04-26
# 32832                  Recife       2611606.0  2020-04-26
# ...

# %%
dfTrab = df[df['city'].isin(['Curitiba', 'Rio', 'Fortaleza', 'São Luiz', 'Recife'])]

dfTrab
# Out:
#              city  city_ibge_code        date  epidemiological_week  \
# 114        Recife       2611606.0  2020-03-12                    11
# 116      Curitiba       4106902.0  2020-03-12                    11
# 151        Recife       2611606.0  2020-03-13                    11
# 153      Curitiba       4106902.0  2020-03-13                    11
# 194        Recife       2611606.0  2020-03-14                    11
# ...           ...             ...         ...                   ...
# 346950   São Luiz       1400605.0  2020-07-11                    28
# 349210  Fortaleza       2304400.0  2020-07-12                    29
# 351343     Recife       2611606.0  2020-07-12                    29
# 351700   Curitiba       4106902.0  2020-07-12                    29
# 352322   São Luiz       1400605.0  2020-07-12                    29
#
#         estimated_population_2019  is_last  is_repeated  \
# 114                     1645727.0    False        False
# ...

# %%
casos_covid = dfTrab[['date', 'epidemiological_week', 'last_available_date', 'is_last', 'is_repeated', 'last_available_confirmed', 'last_available_confirmed_per_100k_inhabitants', 'last_available_death_rate', 'last_available_deaths', 'new_confirmed', 'new_deaths']]

localizacao = dfTrab[['city', 'city_ibge_code', 'estimated_population_2019', 'order_for_place', 'place_type', 'state']]

casos_covid.head()
#localizacao.head()
# Out:
#            date  epidemiological_week last_available_date  is_last  \
# 114  2020-03-12                    11          2020-03-12    False
# 116  2020-03-12                    11          2020-03-12    False
# 151  2020-03-13                    11          2020-03-13    False
# 153  2020-03-13                    11          2020-03-13    False
# 194  2020-03-14                    11          2020-03-14    False
#
#      is_repeated  last_available_confirmed  \
# 114        False                         2
# 116        False                         5
# 151        False                         2
# 153        False                         5
# 194        False                         6
#
#      last_available_confirmed_per_100k_inhabitants  last_available_death_rate  \
# 114                                        0.12153                        0.0
# 116                                        0.25865                        0.0
# ...

# %%
casos_covid.dtypes
#localizacao.columns()
# Out:
# date                                              object
# epidemiological_week                               int64
# last_available_date                               object
# is_last                                             bool
# is_repeated                                         bool
# last_available_confirmed                           int64
# last_available_confirmed_per_100k_inhabitants    float64
# last_available_death_rate                        float64
# last_available_deaths                              int64
# new_confirmed                                      int64
# new_deaths                                         int64
# dtype: object

# %%
casos_covid = casos_covid.astype({
    'last_available_death_rate': 'str',
    'is_last':'int64',
    'is_repeated':'int64'
    })

casos_covid.dtypes
# Out:
# date                                              object
# epidemiological_week                               int64
# last_available_date                               object
# is_last                                            int64
# is_repeated                                        int64
# last_available_confirmed                           int64
# last_available_confirmed_per_100k_inhabitants    float64
# last_available_death_rate                         object
# last_available_deaths                              int64
# new_confirmed                                      int64
# new_deaths                                         int64
# dtype: object
